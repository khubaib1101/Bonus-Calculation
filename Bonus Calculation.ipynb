# %%
# Bonus calculation
total_sale = 1000
bonus = 20
if total_sale >=1000:
  bonus = total_sale * bonus
  print("Your Bonus is =",bonus)
else:
  print("You have sold less than 1000 shirts therefore no bonus for you")
